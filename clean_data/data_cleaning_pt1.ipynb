# %% [markdown]
# ## Circuit Dataset Cleaning

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np

# %%
circuits = pd.read_csv('../datasets/circuits.csv')
circuits.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng  alt  \
# 0  Australia -37.84970  144.96800   10
# 1   Malaysia   2.76083  101.73800   18
# 2    Bahrain  26.03250   50.51060    7
# 3      Spain  41.57000    2.26111  109
# 4     Turkey  40.95170   29.40500  130
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# ...

# %%
circuits_renamed_cols = {'name': 'circuitName', 'location': 'circuitLocation', 'country':'circuitCountry'}
circuits_drop_cols = ['lat', 'lng', 'alt', 'url']
circuits.rename(columns=circuits_renamed_cols, inplace=True)
circuits = circuits.drop(columns=circuits_drop_cols, axis=1)
circuits.columns
circuits.head()
# Out:
#    circuitId   circuitRef                     circuitName circuitLocation  \
# 0          1  albert_park  Albert Park Grand Prix Circuit       Melbourne
# 1          2       sepang    Sepang International Circuit    Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit          Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya        Montmeló
# 4          5     istanbul                   Istanbul Park        Istanbul
#
#   circuitCountry
# 0      Australia
# 1       Malaysia
# 2        Bahrain
# 3          Spain
# 4         Turkey

# %% [markdown]
# ### Laptimes Dataset Cleaning

# %%
laptimes = pd.read_csv('../datasets/lap_times.csv')
laptimes.head()
# Out:
#    raceId  driverId  lap  position      time  milliseconds
# 0     841        20    1         1  1:38.109         98109
# 1     841        20    2         1  1:33.006         93006
# 2     841        20    3         1  1:32.713         92713
# 3     841        20    4         1  1:32.803         92803
# 4     841        20    5         1  1:32.342         92342

# %%
laptimes_ranamed_cols = {'lap' : 'driverLapNumber', 'position' : 'driverfinalRacePosition', 'time' : 'driverLapTime', 'milliseconds': 'driverLapTimeInMilliseconds'}
laptimes.rename(columns=laptimes_ranamed_cols, inplace=True)
laptimes.head()
# Out:
#    raceId  driverId  driverLapNumber  driverfinalRacePosition driverLapTime  \
# 0     841        20                1                        1      1:38.109
# 1     841        20                2                        1      1:33.006
# 2     841        20                3                        1      1:32.713
# 3     841        20                4                        1      1:32.803
# 4     841        20                5                        1      1:32.342
#
#    driverLapTimeInMilliseconds
# 0                        98109
# 1                        93006
# 2                        92713
# 3                        92803
# 4                        92342

# %% [markdown]
# ## Pitstops Datset Cleaning

# %%
pitstops = pd.read_csv('../datasets/pit_stops.csv')
pitstops.head()
# Out:
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841        30     1    1  17:05:52   25.021         25021
# 2     841        17     1   11  17:20:48   23.426         23426
# 3     841         4     1   12  17:22:34   23.251         23251
# 4     841        13     1   13  17:24:10   23.842         23842

# %%
pitstops_renamed_cols = {'stop': 'pitStopNumber', 'lap':'pitStopLap', 'duration':'pitStopDuration', 'milliseconds':'pitStopDurationMilliseconds'}
pitstops_drop_cols = ['time']
pitstops.rename(columns=pitstops_renamed_cols, inplace=True)
pitstops = pitstops.drop(pitstops_drop_cols, axis=1)
pitstops.head()
# Out:
#    raceId  driverId  pitStopNumber  pitStopLap pitStopDuration  \
# 0     841       153              1           1          26.898
# 1     841        30              1           1          25.021
# 2     841        17              1          11          23.426
# 3     841         4              1          12          23.251
# 4     841        13              1          13          23.842
#
#    pitStopDurationMilliseconds
# 0                        26898
# 1                        25021
# 2                        23426
# 3                        23251
# 4                        23842

# %% [markdown]
# ## Status Dataset Cleaning

# %%
status = pd.read_csv('../datasets/status.csv')
status.head()
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %%
status_renamed_cols = {'status':'driverRaceResultStatus'}
status.rename(columns=status_renamed_cols,inplace=True)
status.head()
# Out:
#    statusId driverRaceResultStatus
# 0         1               Finished
# 1         2           Disqualified
# 2         3               Accident
# 3         4              Collision
# 4         5                 Engine

# %% [markdown]
# ## Constructors Dataset Cleaning

# %%
constructors = pd.read_csv('../datasets/constructors.csv')
constructors.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
constructors_rename_cols = {'name':'constructorsName', 'nationality':'constructorsNationality'}
constructors_drop_cols = ['url']
constructors.rename(columns=constructors_rename_cols, inplace=True)
constructors = constructors.drop(constructors_drop_cols, axis=1)
constructors.head()
# Out:
#    constructorId constructorRef constructorsName constructorsNationality
# 0              1        mclaren          McLaren                 British
# 1              2     bmw_sauber       BMW Sauber                  German
# 2              3       williams         Williams                 British
# 3              4        renault          Renault                  French
# 4              5     toro_rosso       Toro Rosso                 Italian

# %% [markdown]
# ## Constructor Results Dataset Clean
